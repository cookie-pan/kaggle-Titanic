# %% [markdown]
# <a href="https://colab.research.google.com/github/cookie-pan/kaggle-Titanic/blob/main/version/%E2%80%9Ctatanic_end_version_ipynb%E2%80%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sklearn

# %%
import numpy as np 
import pandas as pd 
import copy
import warnings 
import seaborn as sns
import matplotlib.pyplot as plt


# Input data files are available in the read-only "../input/" directory
#  (/kaggle/working/) 当前工作路径默认为output路径
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
warnings.filterwarnings('ignore')
# sns.set(style='white',context='notebook',palette='muted')
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %% [markdown]
# # 读取数据

# %%
training = pd.read_csv('train.csv')
testing = pd.read_csv('test.csv')

# %%
train=copy.deepcopy(training)
test=copy.deepcopy(testing)

# %% [markdown]
# # 合并测试集和训练集

# %%
#查看数据是否有异常值
train.describe()
test.describe()
#将两表合并
#ignore_index=True 重新设置合并后的索引，append是创建副本
all=train.append(test,ignore_index=True) 
all
# Out:
#       PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0               1       0.0       3  ...    7.2500   NaN         S
# 1               2       1.0       1  ...   71.2833   C85         C
# 2               3       1.0       3  ...    7.9250   NaN         S
# 3               4       1.0       1  ...   53.1000  C123         S
# 4               5       0.0       3  ...    8.0500   NaN         S
# ...           ...       ...     ...  ...       ...   ...       ...
# 1304         1305       NaN       3  ...    8.0500   NaN         S
# 1305         1306       NaN       1  ...  108.9000  C105         C
# 1306         1307       NaN       3  ...    7.2500   NaN         S
# 1307         1308       NaN       3  ...    8.0500   NaN         S
# 1308         1309       NaN       3  ...   22.3583   NaN         C
#
# [1309 rows x 12 columns]

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
#我们观察到Fare只有一个缺失值
all[all["Fare"].isnull()]  
#Embarked有两个缺失值
all[all["Embarked"].isnull()]
#Age和Cabin需要填充
# Out:
#      PassengerId  Survived  Pclass  ...  Fare Cabin  Embarked
# 61            62       1.0       1  ...  80.0   B28       NaN
# 829          830       1.0       1  ...  80.0   B28       NaN
#
# [2 rows x 12 columns]

# %%
all
# Out:
#       PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0               1       0.0       3  ...    7.2500   NaN         S
# 1               2       1.0       1  ...   71.2833   C85         C
# 2               3       1.0       3  ...    7.9250   NaN         S
# 3               4       1.0       1  ...   53.1000  C123         S
# 4               5       0.0       3  ...    8.0500   NaN         S
# ...           ...       ...     ...  ...       ...   ...       ...
# 1304         1305       NaN       3  ...    8.0500   NaN         S
# 1305         1306       NaN       1  ...  108.9000  C105         C
# 1306         1307       NaN       3  ...    7.2500   NaN         S
# 1307         1308       NaN       3  ...    8.0500   NaN         S
# 1308         1309       NaN       3  ...   22.3583   NaN         C
#
# [1309 rows x 12 columns]

# %% [markdown]
# # 特征分析

# %% [markdown]
# ### 港口数据分析

# %%
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette("hls", 8))
sns.set_context("paper")

sns.barplot(data=train,x='Embarked',y='Survived')
#C港口存活率明显高于其他港口

# %%
#法国登船乘客生存率较高原因可能与其头等舱乘客比例较高有关
#但Q港口的存活率也较高，所以存活率可能与港口相关
sns.factorplot('Pclass',col='Embarked',data=train,kind='count',size=3)

# %% [markdown]
# ### parch分析

# %%
sns.barplot(data=train,x='Parch',y='Survived')
#parch为1-3的存活率要明显高一些
#观察一下parch为1-5的样本量
sns.factorplot('Parch',data=train,kind='count',size=5)

# %% [markdown]
# ### sibsp分析

# %%
sns.barplot(data=train,x='SibSp',y='Survived')
sns.factorplot('SibSp',data=train,kind='count',size=5)

# %% [markdown]
# ### Pclass分析

# %%
sns.barplot(data=train,x='Pclass',y='Survived')

# %% [markdown]
# ### sex分析

# %%
sns.barplot(data=train,x='Sex',y='Survived')

# %%
#查看fare分布
farePlot=sns.distplot(all['Fare'][all['Fare'].notnull()],label='skewness:%.2f'%(all['Fare'].skew()))
farePlot.legend(loc='best')

# %% [markdown]
# # 数据清洗

# %% [markdown]
# ### 码头数据缺失值填充

# %%
all['Embarked'].value_counts(normalize=True)
#大部分的乘客目的地都是S
#我们用S填充缺失值
all.loc[all["Embarked"].isnull(),["Embarked"]]="S"
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# ### 根据pclass对Fare缺失值进行填充

# %%
"""可以看到Fare与阶级线性相关性很大，我们利用Fare缺失值的阶级对他进行填充"""


AgeCorrDf=pd.DataFrame()
AgeCorrDf=all.corr()
AgeCorrDf['Fare'].sort_values()

#得到缺失值旅客是第三阶级的
all[all["Fare"].isnull()]

#用第三阶级的Fare平均值对缺失的Fare进行填充
tmean=all["Fare"][all["Pclass"]==3].mean()
all.loc[all["Fare"].isnull(),["Fare"]]=tmean

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# # 特征工程

# %% [markdown]
# ### Fare对数化处理

# %%
#fare数据呈左偏分布
#对数化处理fare值
all['log_Fare']=all['Fare'].map(lambda x: np.log(x) if x>0 else 0)

# %% [markdown]
# ### SibSp分两类处理

# %%
def sibsp_group(num):
  if num==3 or num==4 or num==5 or num==8 or num==0:
    return 0
  
  else :
    return 1 


all["group_sibsp"]=all["SibSp"].map(sibsp_group)

# %% [markdown]
# ### Parch分两类处理

# %%
def parch_group(num):

  if num==1 or num==3 or num ==2:
    return 1
 
  else :
    return 0
all["group_parch"]=all["Parch"].map(parch_group)

# %% [markdown]
# ### Cabin特征分两类处理

# %%
t=train["Survived"][train["Cabin"].notnull()]
t.value_counts(normalize=True)
all["Survived"].value_counts(normalize=True)
t=train["Survived"][train["Cabin"].isnull()]
t.value_counts(normalize=True)

#有Cabin和无Cabin存活率变化7%


all['Cabin'].replace(np.NaN,0,inplace=True) #把Na值替换为0
all['1_Cabin']=all['Cabin'].map(lambda x: 1 if x!=0 else 0) #把剩下的有cabin的数据存为1
all["C_Cabin"]=all['Cabin'].map(lambda x:str(x)[0])  #把有Cabin的数据的首字符提出来
# print(all["C_Cabin"].value_counts())
sns.barplot(data=all,x="C_Cabin",y='Survived')
sns.factorplot('C_Cabin',data=all,kind='count',size=5)

# %% [markdown]
# ### 在名字中提取信息

# %%
all['Name'].map(lambda x:x.split(',')[1].split('.')[0].strip()).value_counts() 
all["Title"]=all['Name'].map(lambda x:x.split(',')[1].split('.')[0].strip())

title_dict={}
title_dict["Mr"]="Mr"
title_dict["Miss"]="Miss"
title_dict["Mrs"]="Mrs"
title_dict["Rev"]="Royalty"
title_dict["Dr"]="Royalty"
title_dict["Master"]="Royalty"
title_dict["Col"]="Royalty"
title_dict["Mlle"]="Miss"
title_dict["Major"]="Royalty"
title_dict["Ms"]="Miss" #归为女性最多的一类
title_dict["Lady"]="Royalty"
title_dict["Sir"]="Royalty"
title_dict["Mme"]="Royalty"
title_dict["Don"]="Royalty"
title_dict["Capt"]="Royalty"
title_dict["the Countess"]="Royalty"
title_dict["Jonkheer"]="Royalty"
title_dict["Dona"]="Royalty"

all["Title"]=all["Title"].map(title_dict)
all['Title'].value_counts()
# Out:
# Mr         757
# Miss       264
# Mrs        197
# Royalty     91
# Name: Title, dtype: int64

# %% [markdown]
# ### 提取车票中的信息

# %%
ticnum_dict=all['Ticket'].value_counts()
all["Ticket_count"]=all["Ticket"].map(ticnum_dict)
all["Ticket"].map(ticnum_dict).value_counts()
sns.barplot(data=all,x="Ticket_count",y='Survived')

#相同车票人数为2，3，4时存活率较高
#我们把车票人数分为两类
def ticke_num_group(num):
  if (num==2) or (num==3) or (num==4):
    return 1
  else:
    return 0


all["Tiket_cat"]=all["Ticket_count"].map(ticke_num_group)
sns.barplot(data=all,x="Tiket_cat",y='Survived')

# %% [markdown]
# ### 提取同行的人数（parch+sibsp）

# %%
all['familynum']=all['Parch']+all['SibSp']
#查看familyNum与Survived
sns.barplot(data=all,x='familynum',y='Survived')
sns.factorplot('familynum',data=all,kind='count',size=5)


#分成两类
def group_familynum(num):
  if num==1 or num==2 or num==3:
    return 1
  else :
    return 0
all["group_familynum"]=all['familynum'].map(group_familynum)

# %% [markdown]
# ### 用knn对缺失的Age进行填充

# %%
all
# Out:
#       PassengerId  Survived  Pclass  ... Tiket_cat familynum  group_familynum
# 0               1       0.0       3  ...         0         1                1
# 1               2       1.0       1  ...         1         1                1
# 2               3       1.0       3  ...         0         0                0
# 3               4       1.0       1  ...         1         1                1
# 4               5       0.0       3  ...         0         0                0
# ...           ...       ...     ...  ...       ...       ...              ...
# 1304         1305       NaN       3  ...         0         0                0
# 1305         1306       NaN       1  ...         1         0                0
# 1306         1307       NaN       3  ...         0         0                0
# 1307         1308       NaN       3  ...         0         0                0
# 1308         1309       NaN       3  ...         1         2                1
#
# [1309 rows x 22 columns]

# %% [markdown]
# 创建包含建模特征的临时表

# %%
# tem=all[["Pclass","Sex","Age","group_sibsp","Parch","1_Cabin","Tiket_cat","Title"	]]
cat=["Sex","Title","Embarked"]
num=["Pclass","Age","group_sibsp","group_parch","1_Cabin","log_Fare","Tiket_cat","group_familynum"]
tem_cat = pd.get_dummies(all[cat])
tem=pd.concat([tem_cat,all[num]],axis=1)
tem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex_female       1309 non-null   uint8
#  1   Sex_male         1309 non-null   uint8
#  2   Title_Miss       1309 non-null   uint8
#  3   Title_Mr         1309 non-null   uint8
#  4   Title_Mrs        1309 non-null   uint8
#  5   Title_Royalty    1309 non-null   uint8
#  6   Embarked_C       1309 non-null   uint8
#  7   Embarked_Q       1309 non-null   uint8
#  8   Embarked_S       1309 non-null   uint8
#  9   Pclass           1309 non-null   int64
#  10  Age              1046 non-null   float64
#  11  group_sibsp      1309 non-null   int64
#  12  group_parch      1309 non-null   int64
#  13  1_Cabin          1309 non-null   int64
#  14  log_Fare         1309 non-null   float64
#  15  Tiket_cat        1309 non-null   int64
#  16  group_familynum  1309 non-null   int64
# dtypes: float64(2), int64(6), uint8(9)
# memory usage: 93.4 KB

# %%
# !pip install fancyimpute
# Out:
# Requirement already satisfied: fancyimpute in /usr/local/lib/python3.7/dist-packages (0.7.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.2.7)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (3.6.4)
# Requirement already satisfied: knnimpute>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (0.1.0)
# Requirement already satisfied: nose in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.3.7)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.0.2)
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.0.31)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from knnimpute>=0.1.0->fancyimpute) (1.21.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from knnimpute>=0.1.0->fancyimpute) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (1.1.0)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (2.0.10)
# Requirement already satisfied: scs>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (3.1.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (0.6.2.post0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (0.70.12.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy->fancyimpute) (0.1.5.post0)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from multiprocess->cvxpy->fancyimpute) (0.3.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (21.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (57.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (8.12.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (1.11.0)

# %% [markdown]
# knn预测Age填充到原表中

# %%
from fancyimpute import KNN
features_knn_imputed = KNN(k=7).fit_transform(tem)

# print(features_knn_imputed)
tem_df=pd.DataFrame(features_knn_imputed.reshape(1309,-1),columns=list(tem.columns))
# print(train)
all["Age"]=tem_df["Age"]
all.info()
# Out:
# Imputing row 1/1309 with 0 missing, elapsed time: 0.403
# Imputing row 101/1309 with 0 missing, elapsed time: 0.404
# Imputing row 201/1309 with 0 missing, elapsed time: 0.406
# Imputing row 301/1309 with 1 missing, elapsed time: 0.407
# Imputing row 401/1309 with 0 missing, elapsed time: 0.408
# Imputing row 501/1309 with 0 missing, elapsed time: 0.410
# Imputing row 601/1309 with 0 missing, elapsed time: 0.412
# Imputing row 701/1309 with 0 missing, elapsed time: 0.414
# Imputing row 801/1309 with 0 missing, elapsed time: 0.415
# Imputing row 901/1309 with 0 missing, elapsed time: 0.417
# Imputing row 1001/1309 with 0 missing, elapsed time: 0.418
# Imputing row 1101/1309 with 0 missing, elapsed time: 0.420
# Imputing row 1201/1309 with 0 missing, elapsed time: 0.421
# Imputing row 1301/1309 with 0 missing, elapsed time: 0.423
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      1309 non-null   int64
#  1   Survived         891 non-null    float64
#  2   Pclass           1309 non-null   int64
#  3   Name             1309 non-null   object
#  4   Sex              1309 non-null   object
#  5   Age              1309 non-null   float64
#  6   SibSp            1309 non-null   int64
#  7   Parch            1309 non-null   int64
#  8   Ticket           1309 non-null   object
#  9   Fare             1309 non-null   float64
#  10  Cabin            1309 non-null   object
#  11  Embarked         1309 non-null   object
#  12  log_Fare         1309 non-null   float64
#  13  group_sibsp      1309 non-null   int64
#  14  group_parch      1309 non-null   int64
#  15  1_Cabin          1309 non-null   int64
#  16  C_Cabin          1309 non-null   object
#  17  Title            1309 non-null   object
#  18  Ticket_count     1309 non-null   int64
#  19  Tiket_cat        1309 non-null   int64
#  20  familynum        1309 non-null   int64
#  21  group_familynum  1309 non-null   int64
# dtypes: float64(4), int64(11), object(7)
# memory usage: 225.1+ KB

# %%
# tem=pd.DataFrame(all["Name"].map(lambda x:x.split(",")[0]).value_counts())
# tem

# %%
# all["Name"].map(lambda x:x.split(",")[0]).value_counts()

# %% [markdown]
# 分析男性和女性在同一个家族里同生共死的现象

# %%
tem=all["Name"].map(lambda x:x.split(",")[0]).value_counts()
tem_df=pd.DataFrame(all["Name"].map(lambda x:x.split(",")[0]).value_counts())
#创建新特征：每个名字出现的次数
all["Surname"]=all["Name"].map(lambda x:x.split(",")[0])
all["Surname_count"]=all["Surname"].map(tem)

tem_df=tem_df[tem_df["Name"]>1]
teml=list(tem_df.index)




#一个家族男、女性同生共死现象
for i in teml:
  print(i)
  print(all[["Survived","Sex","Age"]][all["Surname"]==i])
# Out:
# Andersson
#       Survived     Sex   Age
# 13         0.0    male  39.0
# 68         1.0  female  17.0
# 119        0.0  female   2.0
# 146        1.0    male  27.0
# 541        0.0  female   9.0
# 542        0.0  female  11.0
# 610        0.0  female  39.0
# 813        0.0  female   6.0
# 850        0.0    male   4.0
# 1105       NaN  female  38.0
# 1211       NaN    male  26.0
# Sage
#       Survived     Sex        Age
# 159        0.0    male  14.495981
# 180        0.0  female  10.577147
# 201        0.0    male  17.955930
# 324        0.0    male  17.955930
# 792        0.0  female  10.577147
# 846        0.0    male  17.955930
# 863        0.0  female  10.577147
# 1079       NaN  female  10.577147
# 1233       NaN    male  37.920581
# 1251       NaN    male  14.500000
# 1256       NaN  female  41.755261
# Goodwin
#       Survived     Sex   Age
# 59         0.0    male  11.0
# 71         0.0  female  16.0
# 386        0.0    male   1.0
# 480        0.0    male   9.0
# 678        0.0  female  43.0
# 683        0.0    male  14.0
# 1030       NaN    male  40.0
# 1031       NaN  female  10.0
# Asplund
#       Survived     Sex   Age
# 25         1.0  female  38.0
# 182        0.0    male   9.0
# 233        1.0  female   5.0
# 261        1.0    male   3.0
# 1045       NaN    male  13.0
# 1065       NaN    male  40.0
# 1117       NaN    male  23.0
# 1270       NaN    male   5.0
# Davies
#       Survived     Sex   Age
# 385        0.0    male  18.0
# 549        1.0    male   8.0
# 565        0.0    male  24.0
# 900        NaN    male  21.0
# 1038       NaN    male  22.0
# 1078       NaN    male  17.0
# 1221       NaN  female  48.0
# Brown
#       Survived     Sex   Age
# 194        1.0  female  44.0
# 345        1.0  female  24.0
# 670        1.0  female  40.0
# 684        0.0    male  60.0
# 1066       NaN  female  15.0
# 1247       NaN  female  59.0
# Panula
#      Survived     Sex   Age
# 50        0.0    male   7.0
# 164       0.0    male   1.0
# 266       0.0    male  16.0
# 638       0.0  female  41.0
# 686       0.0    male  14.0
# 824       0.0    male   2.0
# Skoog
#      Survived     Sex   Age
# 63        0.0    male   4.0
# 167       0.0  female  45.0
# 360       0.0    male  40.0
# 634       0.0  female   9.0
# 642       0.0  female   2.0
# 819       0.0    male  10.0
# Carter
#      Survived     Sex   Age
# 249       0.0    male  54.0
# 390       1.0    male  36.0
# 435       1.0  female  14.0
# 763       1.0  female  36.0
# 802       1.0    male  11.0
# 854       0.0  female  44.0
# Rice
#      Survived     Sex   Age
# 16        0.0    male   2.0
# 171       0.0    male   4.0
# 278       0.0    male   7.0
# 787       0.0    male   8.0
# 885       0.0  female  39.0
# 946       NaN    male  10.0
# Smith
#       Survived     Sex        Age
# 174        0.0    male  56.000000
# 260        0.0    male  33.428571
# 284        0.0    male  39.691757
# 346        1.0  female  40.000000
# 941        NaN    male  24.000000
# 1286       NaN  female  18.000000
# Fortune
#      Survived     Sex   Age
# 27        0.0    male  19.0
# 88        1.0  female  23.0
# 341       1.0  female  24.0
# 438       0.0    male  64.0
# 944       NaN  female  28.0
# 960       NaN  female  60.0
# Johnson
#      Survived     Sex   Age
# 8         1.0  female  27.0
# 172       1.0  female   1.0
# 302       0.0    male  19.0
# 597       0.0    male  49.0
# 719       0.0    male  33.0
# 869       1.0    male   4.0
# Ford
#       Survived     Sex        Age
# 86         0.0    male  16.000000
# 147        0.0  female   9.000000
# 436        0.0  female  21.000000
# 736        0.0  female  48.000000
# 1058       NaN    male  18.000000
# 1180       NaN    male  33.785714
# Lefebre
#       Survived     Sex        Age
# 176        0.0    male   6.597758
# 229        0.0  female   5.532272
# 409        0.0  female   5.532272
# 485        0.0  female   5.854991
# 1023       NaN  female  32.501625
# Williams
#      Survived   Sex        Age
# 17        1.0  male  30.428571
# 155       0.0  male  51.000000
# 304       0.0  male  25.714286
# 735       0.0  male  28.500000
# 914       NaN  male  21.000000
# Ryerson
#       Survived     Sex   Age
# 311        1.0  female  18.0
# 742        1.0  female  21.0
# 915        NaN  female  48.0
# 955        NaN    male  13.0
# 1033       NaN    male  61.0
# Palsson
#       Survived     Sex   Age
# 7          0.0    male   2.0
# 24         0.0  female   8.0
# 374        0.0  female   3.0
# 567        0.0  female  29.0
# 1280       NaN    male   6.0
# Kelly
#      Survived     Sex        Age
# 300       1.0  female  21.785714
# 573       1.0  female  22.071429
# 696       0.0    male  44.000000
# 706       1.0  female  45.000000
# 891       NaN    male  34.500000
# Thomas
#       Survived     Sex        Age
# 803        1.0    male   0.420000
# 995        NaN  female  16.000000
# 1007       NaN    male  34.427244
# 1024       NaN    male  21.045730
# 1223       NaN    male  23.571429
# Baclini
#      Survived     Sex    Age
# 448       1.0  female   5.00
# 469       1.0  female   0.75
# 644       1.0  female   0.75
# 858       1.0  female  24.00
# Hansen
#       Survived     Sex   Age
# 623        0.0    male  21.0
# 704        0.0    male  26.0
# 860        0.0    male  41.0
# 1200       NaN  female  45.0
# Hart
#      Survived     Sex       Age
# 314       0.0    male  43.00000
# 411       0.0    male  20.71001
# 440       1.0  female  45.00000
# 535       1.0  female   7.00000
# Laroche
#       Survived     Sex   Age
# 43         1.0  female   3.0
# 608        1.0  female  22.0
# 685        0.0    male  25.0
# 1187       NaN  female   1.0
# Harris
#      Survived     Sex   Age
# 62        0.0    male  45.0
# 219       0.0    male  30.0
# 230       1.0  female  35.0
# 570       1.0    male  62.0
# Elias
#       Survived   Sex        Age
# 352        0.0  male  15.000000
# 532        0.0  male  17.000000
# 773        0.0  male  25.857143
# 1228       NaN  male  39.000000
# West
#       Survived     Sex    Age
# 58         1.0  female   5.00
# 450        0.0    male  36.00
# 472        1.0  female  33.00
# 1141       NaN  female   0.92
# Johnston
#       Survived     Sex        Age
# 783        0.0    male  34.156188
# 888        0.0  female   1.227850
# 924        NaN  female  29.631647
# 1135       NaN    male   2.422885
# Ware
#       Survived     Sex        Age
# 1169       NaN    male  30.000000
# 1253       NaN  female  31.000000
# 1297       NaN    male  23.000000
# 1307       NaN    male  39.071429
# Harper
#      Survived     Sex   Age
# 52        1.0  female  49.0
# 645       1.0    male  48.0
# 720       1.0  female   6.0
# 848       0.0    male  28.0
# Boulos
#      Survived     Sex        Age
# 140       0.0  female  29.087577
# 598       0.0    male  25.857143
# 852       0.0  female   9.000000
# 971       NaN    male   6.000000
# Gustafsson
#      Survived   Sex   Age
# 104       0.0  male  37.0
# 379       0.0  male  19.0
# 392       0.0  male  28.0
# 876       0.0  male  20.0
# Johansson
#       Survived   Sex   Age
# 103        0.0  male  33.0
# 395        0.0  male  22.0
# 805        0.0  male  31.0
# 1190       NaN  male  29.0
# Goldsmith
#      Survived     Sex   Age
# 165       1.0    male   9.0
# 328       1.0  female  31.0
# 548       0.0    male  33.0
# 933       NaN    male  41.0
# Dean
#       Survived     Sex    Age
# 93         0.0    male  26.00
# 788        1.0    male   1.00
# 923        NaN  female  33.00
# 1245       NaN  female   0.17
# Becker
#       Survived     Sex   Age
# 183        1.0    male   1.0
# 618        1.0  female   4.0
# 1069       NaN  female  36.0
# 1217       NaN  female  12.0
# Olsen
#      Survived   Sex        Age
# 154       0.0  male  29.714284
# 197       0.0  male  42.000000
# 508       0.0  male  28.000000
# 912       NaN  male   9.000000
# Cacic
#       Survived     Sex   Age
# 471        0.0    male  38.0
# 534        0.0  female  30.0
# 928        NaN  female  21.0
# 1201       NaN    male  18.0
# Vander Planke
#       Survived     Sex   Age
# 18         0.0  female  31.0
# 38         0.0  female  18.0
# 333        0.0    male  16.0
# 1036       NaN    male  31.0
# Herman
#       Survived     Sex   Age
# 615        1.0  female  24.0
# 754        1.0  female  48.0
# 1244       NaN    male  49.0
# 1276       NaN  female  24.0
# Hocking
#       Survived     Sex   Age
# 529        0.0    male  23.0
# 774        1.0  female  54.0
# 943        NaN  female  20.0
# 1120       NaN    male  36.0
# Allison
#       Survived     Sex    Age
# 297        0.0  female   2.00
# 305        1.0    male   0.92
# 498        0.0  female  25.00
# 1197       NaN    male  30.00
# Wells
#       Survived     Sex   Age
# 750        1.0  female   4.0
# 980        NaN    male   2.0
# 1153       NaN  female  29.0
# Compton
#       Survived     Sex   Age
# 835        1.0  female  39.0
# 1070       NaN  female  64.0
# 1072       NaN    male  37.0
# Jussila
#      Survived     Sex   Age
# 113       0.0  female  20.0
# 402       0.0  female  21.0
# 579       1.0    male  32.0
# Olsson
#       Survived     Sex   Age
# 281        0.0    male  28.0
# 396        0.0  female  31.0
# 1191       NaN    male  32.0
# Hickman
#      Survived   Sex   Age
# 120       0.0  male  21.0
# 655       0.0  male  24.0
# 665       0.0  male  32.0
# McCoy
#       Survived     Sex        Age
# 301        1.0    male  28.680335
# 330        1.0  female  10.693295
# 1018       NaN  female  10.693295
# Karlsson
#       Survived   Sex   Age
# 478        0.0  male  22.0
# 1086       NaN  male  33.0
# 1114       NaN  male  21.0
# White
#       Survived     Sex   Age
# 102        0.0    male  21.0
# 124        0.0    male  54.0
# 1205       NaN  female  55.0
# Abbott
#       Survived     Sex   Age
# 279        1.0  female  35.0
# 746        0.0    male  16.0
# 1283       NaN    male  13.0
# Svensson
#      Survived   Sex   Age
# 499       0.0  male  24.0
# 851       0.0  male  74.0
# 896       NaN  male  14.0
# Rosblom
#       Survived     Sex   Age
# 254        0.0  female  41.0
# 424        0.0    male  18.0
# 1175       NaN  female   2.0
# Graham
#      Survived     Sex   Age
# 268       1.0  female  58.0
# 332       0.0    male  38.0
# 887       1.0  female  19.0
# van Billiard
#       Survived   Sex        Age
# 153        0.0  male  40.500000
# 1083       NaN  male  11.500000
# 1235       NaN  male  11.411549
# Bourke
#      Survived     Sex        Age
# 188       0.0    male  40.000000
# 593       0.0  female  26.928571
# 657       0.0  female  32.000000
# Thayer
#      Survived     Sex   Age
# 550       1.0    male  17.0
# 581       1.0  female  39.0
# 698       0.0    male  49.0
# O'Brien
#      Survived     Sex        Age
# 186       1.0  female  28.124896
# 364       0.0    male  34.997589
# 552       0.0    male  30.653286
# Douglas
#       Survived     Sex   Age
# 544        0.0    male  50.0
# 1075       NaN  female  27.0
# 1130       NaN  female  48.0
# Kink-Heilmann
#       Survived     Sex   Age
# 184        1.0  female   4.0
# 1056       NaN  female  26.0
# 1285       NaN    male  29.0
# Crosby
#       Survived     Sex   Age
# 540        1.0  female  36.0
# 745        0.0    male  70.0
# 1196       NaN  female  64.0
# Klasen
#       Survived     Sex   Age
# 175        0.0    male  18.0
# 1044       NaN  female  36.0
# 1154       NaN  female   1.0
# Newell
#      Survived     Sex   Age
# 215       1.0  female  31.0
# 393       1.0  female  23.0
# 659       0.0    male  58.0
# Hoyt
#      Survived     Sex        Age
# 224       1.0    male  38.000000
# 486       1.0  female  35.000000
# 793       0.0    male  33.207487
# Peacock
#       Survived     Sex    Age
# 1050       NaN  female  26.00
# 1172       NaN    male   0.75
# 1300       NaN  female   3.00
# Collyer
#      Survived     Sex   Age
# 237       1.0  female   8.0
# 637       0.0    male  31.0
# 801       1.0  female  31.0
# Taussig
#      Survived     Sex   Age
# 262       0.0    male  52.0
# 558       1.0  female  39.0
# 585       1.0  female  18.0
# Murphy
#       Survived     Sex        Age
# 241        1.0  female  14.444398
# 612        1.0  female  14.444398
# 1091       NaN  female  22.456968
# Navratil
#      Survived   Sex   Age
# 148       0.0  male  36.5
# 193       1.0  male   3.0
# 340       1.0  male   2.0
# Minahan
#       Survived     Sex   Age
# 245        0.0    male  44.0
# 412        1.0  female  33.0
# 1302       NaN  female  37.0
# Daly
#       Survived     Sex   Age
# 510        1.0    male  29.0
# 857        1.0    male  51.0
# 1182       NaN  female  30.0
# Carlsson
#       Survived   Sex   Age
# 756        0.0  male  28.0
# 872        0.0  male  33.0
# 1026       NaN  male  24.0
# Touma
#       Survived     Sex   Age
# 255        1.0  female  29.0
# 1052       NaN    male   7.0
# 1174       NaN  female   9.0
# Mallet
#       Survived     Sex   Age
# 817        0.0    male  31.0
# 827        1.0    male   1.0
# 1252       NaN  female  24.0
# Chapman
#       Survived     Sex   Age
# 594        0.0    male  37.0
# 695        0.0    male  52.0
# 1010       NaN  female  29.0
# Peter
#       Survived     Sex        Age
# 128        1.0  female   4.337436
# 533        1.0  female  26.527686
# 1308       NaN    male   6.338699
# Quick
#       Survived     Sex   Age
# 506        1.0  female  33.0
# 530        1.0  female   2.0
# 1094       NaN  female   8.0
# Hays
#       Survived     Sex   Age
# 310        1.0  female  24.0
# 820        1.0  female  52.0
# 1199       NaN    male  55.0
# Van Impe
#      Survived     Sex   Age
# 419       0.0  female  10.0
# 595       0.0    male  36.0
# 799       0.0  female  30.0
# Keane
#      Survived     Sex        Age
# 303       1.0  female  25.736217
# 790       0.0    male  42.714286
# 907       NaN    male  35.000000
# Phillips
#       Survived     Sex   Age
# 427        1.0  female  19.0
# 1077       NaN  female  21.0
# 1193       NaN    male  43.0
# Warren
#       Survived     Sex        Age
# 366        1.0  female  60.000000
# 1127       NaN    male  64.000000
# 1158       NaN    male  29.939463
# Meyer
#      Survived     Sex        Age
# 34        0.0    male  28.000000
# 375       1.0  female  50.298691
# 808       0.0    male  39.000000
# Dodge
#       Survived     Sex   Age
# 445        1.0    male   4.0
# 1184       NaN    male  53.0
# 1265       NaN  female  54.0
# Widener
#       Survived     Sex   Age
# 377        0.0    male  27.0
# 1109       NaN  female  50.0
# 1298       NaN    male  50.0
# Samaan
#       Survived   Sex        Age
# 48         0.0  male  24.391714
# 920        NaN  male  24.391714
# 1188       NaN  male  24.391714
# Nakid
#       Survived     Sex   Age
# 381        1.0  female   1.0
# 622        1.0    male  20.0
# 1224       NaN  female  19.0
# Coutts
#      Survived     Sex   Age
# 348       1.0    male   3.0
# 489       1.0    male   9.0
# 940       NaN  female  36.0
# Giles
#       Survived   Sex   Age
# 861        0.0  male  21.0
# 1239       NaN  male  24.0
# 1261       NaN  male  21.0
# Flynn
#      Survived   Sex        Age
# 428       0.0  male  33.428571
# 572       1.0  male  36.000000
# 825       0.0  male  21.996561
# Frauenthal
#       Survived     Sex        Age
# 334        1.0  female  43.814887
# 660        1.0    male  50.000000
# 1295       NaN    male  43.000000
# Moubarek
#       Survived     Sex        Age
# 65         1.0    male   6.500054
# 709        1.0    male   6.500054
# 1116       NaN  female  29.087577
# Oreskovic
#       Survived     Sex   Age
# 404        0.0  female  20.0
# 725        0.0    male  20.0
# 1171       NaN  female  23.0
# Jensen
#      Survived   Sex   Age
# 640       0.0  male  20.0
# 721       0.0  male  17.0
# 771       0.0  male  48.0
# Cor
#       Survived   Sex   Age
# 646        0.0  male  19.0
# 947        NaN  male  35.0
# 1225       NaN  male  27.0
# Nilsson
#       Survived     Sex   Age
# 315        1.0  female  26.0
# 1088       NaN  female  18.0
# 1152       NaN    male  21.0
# Howard
#       Survived     Sex        Age
# 904        NaN    male  63.000000
# 1104       NaN  female  60.000000
# 1159       NaN  female  21.291352
# Richards
#      Survived     Sex    Age
# 407       1.0    male   3.00
# 437       1.0  female  24.00
# 831       1.0    male   0.83
# Drew
#       Survived     Sex   Age
# 416        1.0  female  34.0
# 1085       NaN    male   8.0
# 1138       NaN    male  42.0
# Danbom
#       Survived     Sex    Age
# 423        0.0  female  28.00
# 616        0.0    male  34.00
# 1092       NaN    male   0.33
# Moran
#      Survived     Sex        Age
# 5         0.0    male  33.848755
# 109       1.0  female  10.676389
# 768       0.0    male  28.616884
# Spedden
#       Survived     Sex   Age
# 319        1.0  female  40.0
# 1087       NaN    male   6.0
# 1133       NaN    male  45.0
# Sandstrom
#       Survived     Sex   Age
# 10         1.0  female   4.0
# 394        1.0  female  24.0
# 1008       NaN  female   1.0
# Wick
#       Survived     Sex   Age
# 318        1.0  female  31.0
# 856        1.0  female  45.0
# 1108       NaN    male  57.0
# Caldwell
#      Survived     Sex    Age
# 78        1.0    male   0.83
# 323       1.0  female  22.00
# 898       NaN    male  26.00
# Larsson
#      Survived   Sex   Age
# 231       0.0  male  29.0
# 713       0.0  male  29.0
# Angle
#       Survived     Sex   Age
# 518        1.0  female  36.0
# 1081       NaN    male  34.0
# Carr
#       Survived     Sex   Age
# 208        1.0  female  16.0
# 1204       NaN  female  37.0
# Betros
#       Survived   Sex        Age
# 378        0.0  male  20.000000
# 1230       NaN  male  24.214285
# Snyder
#       Survived     Sex   Age
# 903        NaN  female  23.0
# 1178       NaN    male  24.0
# Ryan
#      Survived   Sex        Age
# 517       0.0  male  27.567217
# 998       NaN  male  40.285714
# Wiklund
#       Survived   Sex   Age
# 371        0.0  male  18.0
# 1123       NaN  male  21.0
# Coleff
#      Survived   Sex   Age
# 514       0.0  male  24.0
# 663       0.0  male  36.0
# Hold
#       Survived     Sex   Age
# 236        0.0    male  44.0
# 1139       NaN  female  29.0
# Louch
#      Survived     Sex   Age
# 432       1.0  female  42.0
# 921       NaN    male  50.0
# Franklin
#       Survived   Sex        Age
# 932        NaN  male  48.452333
# 1177       NaN  male  36.285714
# Silvey
#      Survived     Sex   Age
# 434       0.0    male  50.0
# 577       1.0  female  39.0
# Thorneycroft
#      Survived     Sex        Age
# 431       1.0  female  22.625596
# 639       0.0    male  27.248210
# Jacobsohn
#      Survived     Sex   Age
# 217       0.0    male  42.0
# 600       1.0  female  24.0
# Jefferys
#       Survived   Sex   Age
# 922        NaN  male  24.0
# 1210       NaN  male  22.0
# Kiernan
#       Survived   Sex        Age
# 214        0.0  male  41.285714
# 1012       NaN  male  41.285714
# Cumings
#       Survived     Sex   Age
# 1          1.0  female  38.0
# 1125       NaN    male  39.0
# Rothschild
#      Survived     Sex   Age
# 513       1.0  female  54.0
# 911       NaN    male  55.0
# Clarke
#       Survived     Sex   Age
# 426        1.0  female  28.0
# 1219       NaN    male  29.0
# Risien
#       Survived     Sex        Age
# 538        0.0    male  19.224731
# 1273       NaN  female  35.560001
# Ali
#      Survived   Sex   Age
# 210       0.0  male  24.0
# 784       0.0  male  25.0
# Beane
#      Survived     Sex   Age
# 543       1.0    male  32.0
# 546       1.0  female  19.0
# Strom
#      Survived     Sex   Age
# 205       0.0  female   2.0
# 251       0.0  female  29.0
# Gale
#       Survived   Sex   Age
# 405        0.0  male  34.0
# 1292       NaN  male  38.0
# Harder
#       Survived     Sex   Age
# 370        1.0    male  25.0
# 1255       NaN  female  25.0
# Lahtinen
#       Survived     Sex   Age
# 312        0.0  female  26.0
# 1040       NaN    male  30.0
# Hamalainen
#      Survived     Sex    Age
# 247       1.0  female  24.00
# 755       1.0    male   0.67
# Hirvonen
#      Survived     Sex   Age
# 479       1.0  female   2.0
# 895       NaN  female  22.0
# Buckley
#       Survived     Sex   Age
# 997        NaN    male  21.0
# 1004       NaN  female  18.5
# Foley
#       Survived   Sex        Age
# 993        NaN  male  40.285714
# 1272       NaN  male  26.000000
# Hippach
#      Survived     Sex   Age
# 329       1.0  female  16.0
# 523       1.0  female  44.0
# Aks
#       Survived     Sex    Age
# 855        1.0  female  18.00
# 1198       NaN    male   0.83
# Connolly
#      Survived     Sex   Age
# 289       1.0  female  22.0
# 897       NaN  female  30.0
# Stengel
#       Survived     Sex   Age
# 991        NaN  female  43.0
# 1068       NaN    male  54.0
# Bishop
#      Survived     Sex   Age
# 291       1.0  female  19.0
# 484       1.0    male  25.0
# Lines
#       Survived     Sex   Age
# 853        1.0  female  16.0
# 1282       NaN  female  51.0
# Stanley
#      Survived     Sex   Age
# 494       0.0    male  21.0
# 649       1.0  female  23.0
# Renouf
#      Survived     Sex   Age
# 476       0.0    male  34.0
# 726       1.0  female  30.0
# Khalil
#       Survived     Sex        Age
# 976        NaN    male  23.666723
# 1140       NaN  female  15.000327
# Dennis
#       Survived   Sex   Age
# 320        0.0  male  22.0
# 1176       NaN  male  36.0
# Wright
#       Survived     Sex   Age
# 555        0.0    male  62.0
# 1053       NaN  female  26.0
# Fleming
#       Survived     Sex        Age
# 306        1.0  female  30.038479
# 1173       NaN  female  24.357143
# Dyker
#       Survived     Sex   Age
# 981        NaN  female  22.0
# 1063       NaN    male  23.0
# Penasco y Castellana
#      Survived     Sex   Age
# 307       1.0  female  17.0
# 505       0.0    male  18.0
# Andrews
#      Survived     Sex   Age
# 275       1.0  female  63.0
# 806       0.0    male  39.0
# Straus
#       Survived     Sex   Age
# 972        NaN    male  67.0
# 1005       NaN  female  63.0
# Beckwith
#      Survived     Sex   Age
# 248       1.0    male  37.0
# 871       1.0  female  47.0
# Duran y More
#       Survived     Sex   Age
# 866        1.0  female  27.0
# 1111       NaN  female  30.0
# Abelseth
#       Survived     Sex   Age
# 948        NaN    male  25.0
# 1236       NaN  female  16.0
# Hagland
#      Survived   Sex        Age
# 451       0.0  male  25.545463
# 490       0.0  male  25.545463
# Lobb
#      Survived     Sex   Age
# 253       0.0    male  30.0
# 617       0.0  female  26.0
# Abelson
#      Survived     Sex   Age
# 308       0.0    male  30.0
# 874       1.0  female  28.0
# del Carlo
#      Survived     Sex   Age
# 361       0.0    male  29.0
# 906       NaN  female  24.0
# Goldenberg
#      Survived     Sex        Age
# 453       1.0    male  49.000000
# 849       1.0  female  21.608621
# Kenyon
#       Survived     Sex        Age
# 457        1.0  female  51.523303
# 1136       NaN    male  41.000000
# Bradley
#      Survived     Sex        Age
# 507       1.0    male  45.446243
# 954       NaN  female  22.000000
# Mellinger
#      Survived     Sex   Age
# 272       1.0  female  41.0
# 446       1.0  female  13.0
# Zakarian
#       Survived   Sex   Age
# 1027       NaN  male  26.5
# 1062       NaN  male  27.0
# O'Connor
#       Survived   Sex        Age
# 459        0.0  male  35.071429
# 1271       NaN  male  34.000000
# Canavan
#       Survived     Sex   Age
# 501        0.0  female  21.0
# 1279       NaN    male  21.0
# Davison
#      Survived     Sex        Age
# 347       1.0  female  22.625596
# 949       NaN    male  27.248210
# Fox
#       Survived   Sex        Age
# 344        0.0  male  36.000000
# 1162       NaN  male  35.571429
# Morley
#      Survived   Sex   Age
# 461       0.0  male  34.0
# 705       0.0  male  39.0
# Burns
#      Survived     Sex   Age
# 337       1.0  female  41.0
# 957       NaN  female  18.0
# Barbara
#      Survived     Sex   Age
# 362       0.0  female  45.0
# 702       0.0  female  18.0
# Braund
#      Survived   Sex   Age
# 0         0.0  male  22.0
# 477       0.0  male  29.0
# Duff Gordon
#      Survived     Sex   Age
# 556       1.0  female  48.0
# 599       1.0    male  49.0
# Andrew
#       Survived   Sex   Age
# 144        0.0  male  18.0
# 1095       NaN  male  25.0
# Lennon
#       Survived     Sex        Age
# 46         0.0    male  34.997589
# 1164       NaN  female  14.444398
# Marvin
#       Survived     Sex   Age
# 748        0.0    male  19.0
# 1073       NaN  female  18.0
# Lindell
#       Survived     Sex   Age
# 605        0.0    male  36.0
# 1250       NaN  female  30.0
# Rogers
#       Survived   Sex        Age
# 45         0.0  male  26.571429
# 1208       NaN  male  19.000000
# Zabour
#      Survived     Sex       Age
# 111       0.0  female  14.50000
# 240       0.0  female  14.49915
# Attalah
#      Survived     Sex   Age
# 114       0.0  female  17.0
# 244       0.0    male  30.0
# Baxter
#      Survived     Sex   Age
# 118       0.0    male  24.0
# 299       1.0  female  50.0
# Moore
#      Survived   Sex        Age
# 121       0.0  male  33.785714
# 958       NaN  male  47.000000
# Webber
#      Survived     Sex        Age
# 123       1.0  female  32.500000
# 511       0.0    male  24.928571
# Turpin
#      Survived     Sex   Age
# 41        0.0  female  27.0
# 117       0.0    male  29.0
# Moor
#      Survived     Sex   Age
# 751       1.0    male   6.0
# 823       1.0  female  27.0
# Robins
#      Survived     Sex   Age
# 132       0.0  female  47.0
# 916       NaN    male  50.0
# Weisz
#      Survived     Sex   Age
# 133       1.0  female  29.0
# 992       NaN    male  27.0
# Nicola-Yarred
#      Survived     Sex   Age
# 39        1.0  female  14.0
# 125       1.0    male  12.0
# Holverson
#      Survived     Sex   Age
# 35        0.0    male  42.0
# 383       1.0  female  35.0
# Frolicher-Stehli
#       Survived     Sex   Age
# 587        1.0    male  60.0
# 1288       NaN  female  48.0
# Hakkarainen
#      Survived     Sex   Age
# 142       1.0  female  24.0
# 403       0.0    male  28.0
# Arnold-Franchi
#      Survived     Sex   Age
# 49        0.0  female  18.0
# 353       0.0    male  25.0
# Gibson
#       Survived     Sex   Age
# 1259       NaN  female  45.0
# 1293       NaN  female  22.0
# Faunthorpe
#       Survived     Sex   Age
# 53         1.0  female  29.0
# 1168       NaN    male  40.0
# Kimball
#      Survived     Sex   Age
# 621       1.0    male  42.0
# 935       NaN  female  45.0
# Bryhl
#       Survived     Sex   Age
# 728        0.0    male  25.0
# 1166       NaN  female  20.0
# Ilmakangas
#      Survived     Sex   Age
# 729       0.0  female  25.0
# 909       NaN  female  27.0
# Chambers
#      Survived     Sex   Age
# 724       1.0    male  27.0
# 809       1.0  female  33.0
# Kink
#       Survived     Sex   Age
# 69         0.0    male  26.0
# 1267       NaN  female  22.0
# Carrau
#       Survived   Sex   Age
# 83         0.0  male  28.0
# 1294       NaN  male  17.0
# Backstrom
#      Survived     Sex   Age
# 85        1.0  female  33.0
# 206       0.0    male  32.0
# Bowen
#       Survived     Sex   Age
# 624        0.0    male  21.0
# 1266       NaN  female  45.0
# Yasbeck
#      Survived     Sex   Age
# 620       0.0    male  27.0
# 830       1.0  female  15.0
# Ostby
#      Survived     Sex   Age
# 54        0.0    male  65.0
# 917       NaN  female  22.0
# Chaffee
#      Survived     Sex   Age
# 92        0.0    male  46.0
# 905       NaN  female  47.0
# Greenfield
#       Survived     Sex   Age
# 97         1.0    male  23.0
# 1241       NaN  female  45.0
# Doling
#      Survived     Sex   Age
# 98        1.0  female  34.0
# 651       1.0  female  18.0
# Kantor
#      Survived     Sex   Age
# 99        0.0    male  34.0
# 316       1.0  female  24.0
# Cavendish
#      Survived     Sex   Age
# 741       0.0    male  36.0
# 987       NaN  female  76.0
# Petroff
#      Survived   Sex        Age
# 101       0.0  male  29.285714
# 877       0.0  male  19.000000
# McNamee
#       Survived     Sex   Age
# 743        0.0    male  24.0
# 1274       NaN  female  19.0
# Astor
#       Survived     Sex   Age
# 700        1.0  female  18.0
# 1093       NaN    male  47.0
# Pokrnic
#       Survived   Sex   Age
# 1160       NaN  male  17.0
# 1194       NaN  male  24.0
# Chronopoulos
#       Survived   Sex   Age
# 73         0.0  male  26.0
# 1006       NaN  male  18.0
# Allen
#      Survived     Sex   Age
# 4         0.0    male  35.0
# 730       1.0  female  29.0
# Jonsson
#       Survived   Sex   Age
# 569        1.0  male  32.0
# 1209       NaN  male  27.0
# Karun
#      Survived     Sex   Age
# 691       1.0  female   4.0
# 931       NaN    male  39.0
# Lam
#      Survived   Sex        Age
# 692       1.0  male  29.499919
# 826       0.0  male  29.499919
# Cardeza
#       Survived     Sex   Age
# 679        1.0    male  36.0
# 1234       NaN  female  58.0
# Bonnell
#       Survived     Sex   Age
# 11         1.0  female  58.0
# 1291       NaN  female  30.0
# Calic
#      Survived   Sex   Age
# 163       0.0  male  17.0
# 500       0.0  male  17.0
# Saad
#      Survived   Sex   Age
# 693       0.0  male  25.0
# 832       0.0  male  27.5
# McGowan
#       Survived     Sex   Age
# 22         1.0  female  15.0
# 1097       NaN  female  35.0
# Watt
#       Survived     Sex   Age
# 161        1.0  female  40.0
# 1011       NaN  female  12.0
# Nasser
#      Survived     Sex   Age
# 9         1.0  female  14.0
# 122       0.0    male  32.5
# Cribb
#       Survived     Sex   Age
# 160        0.0    male  44.0
# 1016       NaN  female  17.0
# McCarthy
#       Survived     Sex        Age
# 6          0.0    male  54.000000
# 1195       NaN  female  24.357143
# Davidson
#      Survived     Sex   Age
# 671       0.0    male  31.0
# 983       NaN  female  27.0
# Mahon
#       Survived     Sex        Age
# 1107       NaN  female  21.689265
# 1147       NaN    male  35.571429
# Taylor
#      Survived     Sex       Age
# 669       1.0  female  47.91979
# 712       1.0    male  48.00000
# Dick
#      Survived     Sex   Age
# 690       1.0    male  31.0
# 781       1.0  female  17.0
# Caram
#       Survived     Sex        Age
# 578        0.0  female  15.000328
# 1257       NaN    male  23.666723
# Futrelle
#      Survived     Sex   Age
# 3         1.0  female  35.0
# 137       0.0    male  37.0
# Clark
#       Survived     Sex   Age
# 1143       NaN    male  27.0
# 1163       NaN  female  26.0
# Spencer
#       Survived     Sex        Age
# 31         1.0  female  27.146221
# 1207       NaN    male  57.000000
# Cook
#       Survived     Sex   Age
# 668        0.0    male  43.0
# 1113       NaN  female  22.0
# Pears
#      Survived     Sex   Age
# 151       1.0  female  22.0
# 336       0.0    male  29.0
# de Messemaeker
#       Survived     Sex   Age
# 559        1.0  female  36.0
# 1151       NaN    male  36.5
# Christy
#       Survived     Sex   Age
# 580        1.0  female  25.0
# 1132       NaN  female  45.0

# %%
all["tem_female_dead"]=np.NaN
all["tem_male_dead"]=np.NaN
for i in teml:
  # print(i)
  try:
    t=all[["Survived"]][(all["Surname"]==i)&(all["Sex"]=="female")&(all["Survived"].notnull())].value_counts(normalize=True)[0]
  except KeyError:
    t=np.NaN
  all["tem_female_dead"][(all["Surname"]==i)&(all["Sex"]=="female")]=t

for i in teml:
  # print(i)
  try:
    t=all[["Survived"]][(all["Surname"]==i)&(all["Sex"]=="male")&(all["Survived"].notnull())].value_counts(normalize=True)[0]
  except KeyError:
    t=np.NaN
  all["tem_male_dead"][(all["Surname"]==i)&(all["Sex"]=="male")]=t

# %%
all["tem_male_dead"][(all["Surname"]==teml[0])&(all["Sex"]=="male")]
# Out:
# 13      0.666667
# 146     0.666667
# 850     0.666667
# 1211    0.666667
# Name: tem_male_dead, dtype: float64

# %% [markdown]
# 将同一个家族的男、女性死亡率超过50%的年龄改为“易死亡年龄”

# %%
all["Age"][(all["Survived"].isnull())&(all["Surname_count"]>1)&(all["tem_female_dead"]<0.5)]=6

all["Age"][(all["Survived"].isnull())&(all["Surname_count"]>1)&(all["tem_female_dead"]>=0.5)]=60
all["Sex"][(all["Survived"].isnull())&(all["Surname_count"]>1)&(all["tem_female_dead"]>=0.5)]="male"

#男性同生现象不是很明显，对精确度没有什么显著影响
all["Age"][(all["Survived"].isnull())&(all["Surname_count"]>1)&(all["tem_male_dead"]<0.5)]=6
all["Sex"][(all["Survived"].isnull())&(all["Surname_count"]>1)&(all["tem_male_dead"]<0.5)]="female"

all["Age"][(all["Survived"].isnull())&(all["Surname_count"]>1)&(all["tem_male_dead"]>=0.5)]=60

# %%
#这个家族女性死亡的概率
# print(teml[3])
# t=all[["Survived"]][(all["Surname"]==teml[3])&(all["Sex"]=="female")].value_counts(normalize=True)[0]
# all["tem_female_dead"]=100
# all["tem_female_dead"][(all["Surname"]==teml[0])&(all["Sex"]=="female")]=t
# all["tem_female_dead"][(all["Surname"]==teml[0])&(all["Sex"]=="female")]

# %% [markdown]
# ### 分类数据hot化

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()



# tem=pd.concat([tem_cat,all[num]],axis=1)
# tem.info()
# tem_num=pd.DataFrame(std.fit_transform(all[num]),columns=num)
#

cat=["Sex","Title","Embarked"]
num=["Pclass","Age","group_sibsp","group_parch","1_Cabin","log_Fare","Tiket_cat","group_familynum","familynum","Ticket_count"]


num_new=["Pclass","group_sibsp","group_parch","1_Cabin","Tiket_cat"]
data=pd.concat([tem_cat,all[num]],axis=1)

# %%
data
# Out:
#       Sex_female  Sex_male  ...  familynum  Ticket_count
# 0              0         1  ...          1             1
# 1              1         0  ...          1             2
# 2              1         0  ...          0             1
# 3              1         0  ...          1             2
# 4              0         1  ...          0             1
# ...          ...       ...  ...        ...           ...
# 1304           0         1  ...          0             1
# 1305           1         0  ...          0             3
# 1306           0         1  ...          0             1
# 1307           0         1  ...          0             1
# 1308           0         1  ...          2             3
#
# [1309 rows x 19 columns]

# %%
tem=pd.concat([all[cat],all[num]],axis=1)
tem=tem[:891]
tem_s=train["Survived"]
figure_data=pd.concat([tem,tem_s],axis=1)

# %%
#热力图，查看Survived与其他特征间相关性大小
plt.figure(figsize=(10,10))
sns.heatmap(figure_data.corr(),cmap='BrBG',annot=True,
           linewidths=.5)
plt.xticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <a list of 11 Text major ticklabel objects>)

# %%
data.columns
# Out:
# Index(['Sex_female', 'Sex_male', 'Title_Miss', 'Title_Mr', 'Title_Mrs',
#        'Title_Royalty', 'Embarked_C', 'Embarked_Q', 'Embarked_S', 'Pclass',
#        'Age', 'group_sibsp', 'group_parch', '1_Cabin', 'log_Fare', 'Tiket_cat',
#        'group_familynum', 'familynum', 'Ticket_count'],
#       dtype='object')

# %%
# data.drop([ 'familynum'],axis=1,inplace=True)

# %%
data_train=data[:891]
data_test=data[891:1310]

data_tar=train["Survived"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# X_train,X_test,y_train,y_test=train_test_split(data_train,data_tar)
# print(X_train.shape)
# print(X_test.shape)

print(data_test.shape)
data_train=np.array(data_train).reshape(891,-1)
data_test=np.array(data_test).reshape(418,-1)

print(data_train.shape)
# Out:
# (418, 19)
# (891, 19)

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV,cross_val_score,StratifiedKFold

#设置kfold，交叉采样法拆分数据集
kfold=StratifiedKFold(n_splits=10)

#汇总不同模型算法
classifiers=[]
classifiers.append(SVC())
classifiers.append(DecisionTreeClassifier())
classifiers.append(RandomForestClassifier())
classifiers.append(ExtraTreesClassifier())
classifiers.append(GradientBoostingClassifier())
classifiers.append(KNeighborsClassifier())
classifiers.append(LogisticRegression())
classifiers.append(LinearDiscriminantAnalysis())

# %%
cv_results=[]
for classifier in classifiers:
    cv_results.append(cross_val_score(classifier,data_train,data_tar,
                                      scoring='accuracy',cv=kfold,n_jobs=-1))
    
#求出模型得分的均值和标准差
cv_means=[]
cv_std=[]
for cv_result in cv_results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())
models_accuracy=pd.DataFrame({'cv_mean':cv_means,
                     'cv_std':cv_std,
                     'algorithm':['SVC','DecisionTreeCla','RandomForestCla','ExtraTreesCla',
                                  'GradientBoostingCla','KNN','LR','LinearDiscrimiAna']})

models_accuracy
# Out:
#     cv_mean    cv_std            algorithm
# 0  0.766617  0.050583                  SVC
# 1  0.767740  0.040994      DecisionTreeCla
# 2  0.814881  0.046035      RandomForestCla
# 3  0.801348  0.033711        ExtraTreesCla
# 4  0.829413  0.039780  GradientBoostingCla
# 5  0.792397  0.038822                  KNN
# 6  0.822672  0.034368                   LR
# 7  0.819301  0.028194    LinearDiscrimiAna

# %% [markdown]
# 可视化查看代码的各种表现

# %%
cvResFacet=sns.FacetGrid(models_accuracy.sort_values(by='cv_mean',ascending=False),sharex=False,
            sharey=False,aspect=2)
cvResFacet.map(sns.barplot,'cv_mean','algorithm',**{'xerr':cv_std},
               palette='muted')
cvResFacet.set(xlim=(0.7,0.9))
cvResFacet.add_legend()

# %% [markdown]
# 模型调优

# %%
#GradientBoostingClassifier模型
# GBC = GradientBoostingClassifier()
# param_info = {'loss' : ["deviance"],
#               'n_estimators' : [100,200,300],
#               'learning_rate': [0.1, 0.05, 0.01],
#               'max_depth': [4, 8],
#               'min_samples_leaf': [100,150],
#               'max_features': [0.3, 0.1] 
#               }
# modelgsGBC = GridSearchCV(GBC,param_grid = param_info, cv=kfold, 
#                                      scoring="accuracy", n_jobs= -1, verbose = 1)
# modelgsGBC.fit(data_train,data_tar)

# #LogisticRegression模型
# modelLR=LogisticRegression()
# LR_param_info = {'C' : [1,2,3],
#                 'penalty':['l1','l2']}
# modelgsLR = GridSearchCV(modelLR,param_grid = LR_param_info, cv=kfold, 
#                                      scoring="accuracy", n_jobs= -1, verbose = 1)
# modelgsLR.fit(data_train,data_tar)

# print("GBC_best_accu:",modelgsGBC.best_score_)
# print("LR_best_accu:",modelgsLR.best_score_)

# %%
GBC=GradientBoostingClassifier()
GBC.fit(data_train,data_tar)
LR=LogisticRegression()
LR.fit(data_train,data_tar)
# Out:
# LogisticRegression()

# %%
print("GBC_best_accu:",GBC.score(data_train,data_tar))
print("LR_best_accu:",LR.score(data_train,data_tar))
# Out:
# GBC_best_accu: 0.9012345679012346
# LR_best_accu: 0.8249158249158249

# %% [markdown]
# 比较这两种算法的roc图

# %%
modelgsGBCtestpre_y=GBC.predict(data_train).astype(int)
modelgsLRtestpre_y=LR.predict(data_train).astype(int)
#画图
from sklearn.metrics import roc_curve, auc  ###计算roc和auc
# Compute ROC curve and ROC area for each class
fpr_G,tpr_G,threshold_G = roc_curve(data_tar, modelgsGBCtestpre_y) ###计算真正率和假正率
roc_auc_G = auc(fpr_G,tpr_G) ###计算auc的值
fpr_R,tpr_R,threshold_R = roc_curve(data_tar, modelgsLRtestpre_y) ###计算真正率和假正率
roc_auc_R = auc(fpr_R,tpr_R) ###计算auc的值

plt.figure()
lw = 2
plt.figure(figsize=(10,10))
plt.plot(fpr_G, tpr_G, color='r',
         lw=lw, label='ROC curve (area = %0.3f)' % roc_auc_G) ###假正率为横坐标，真正率为纵坐标做曲线

plt.plot(fpr_R, tpr_R, color='b',
         lw=lw, label='ROC curve (area = %0.3f)' % roc_auc_R) ###假正率为横坐标，真正率为纵坐标做曲线
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Titanic  Model')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# 通过观察roc和auc可以看出GBC算法更好

# %% [markdown]
# 计算混淆矩阵

# %%
#混淆矩阵
from sklearn.metrics import confusion_matrix
print('GradientBoostingClassifier模型混淆矩阵为\n',confusion_matrix(data_tar.astype(int).astype(str),modelgsGBCtestpre_y.astype(str)))
print('LinearRegression模型混淆矩阵为\n',confusion_matrix(data_tar.astype(int).astype(str),modelgsLRtestpre_y.astype(str)))
# Out:
# GradientBoostingClassifier模型混淆矩阵为
#  [[516  33]
#  [ 55 287]]
# LinearRegression模型混淆矩阵为
#  [[476  73]
#  [ 83 259]]

# %%
# from sklearn.model_selection import cross_val_score
import csv
# for i in [0.001,0.01,0.1,1,10,100]:
#     logreg=LogisticRegression(C=i)  #c越小正则化越强
#     logreg.fit(data_train,data_tar)
#     acu_array=cross_val_score(logreg,data_train,data_tar, cv=10, scoring='accuracy')
    
#     print("正则系数",i,"mean__accuracy:",acu_array.mean())
    
predict_data=pd.DataFrame(LR.predict(data_test).astype(int).reshape(-1,1),columns=["Survived"])
submission=pd.concat([testing["PassengerId"],predict_data],axis=1)

file_name= "submission"+".csv"
submission.to_csv(file_name,index=False)



    # print(logreg.score(X_train,y_train))
    # print(logreg.score(X_test,y_test))

# %%
# from sklearn.preprocessing import PolynomialFeatures

# polynomial = PolynomialFeatures(degree=3)
# X_poly_train=polynomial.fit_transform(X_train)
# # print(X_poly.shape)
# X_poly_test=polynomial.fit_transform(X_test)

# logreg=LogisticRegression()  #c越小正则化越强
# logreg.fit(X_poly_train,y_train)
# print(logreg.score(X_poly_train,y_train))
# print(logreg.score(X_poly_test,y_test))

# %%
# logreg=LogisticRegression(C=1)
# logreg.fit(X_train,y_train)


# with open ("submission.csv","w",newline="") as fp:
#         writer = csv.writer(fp)
#         writer.writerow([test, 'tested_positive'])

# %%
# print("class2`s mean age:{}".format(train[['Pclass',"Age"]][train["Pclass"]==2].mean()))
# print("class3`s mean age:{}".format(train[['Pclass',"Age"]][train["Pclass"]==3].mean()))
# cabin_1=train[train["Pclass"]==1]["Age"]
# print(cabin_1.hist())
# cabin_2=none_u_cabin[t_df["Pclass"]==2]
# print(cabin_2.hist())
# cabin_3=none_u_cabin[t_df["Pclass"]==3]
# print(cabin_3.hist())
